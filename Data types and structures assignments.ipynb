# %% [markdown]
# # Q.1  Data Types and structure..
# Q.1 What are data structure and why are they important?
#   - Data structures are formats that organise store and process data in
#     computer systems
#
#   They are essential for coding and building software applications
#
# Q.2 Explain the difference between mutable and immutable data types with example
#   - Mutable data types :- means we can modify this data types after defining or creating a variable or object
#     for example
#
#     1.list      [1,2,33]  >>>> ordered and mutable collection of data
#
#     2.set     {1,2,656} >>> unordered collection of data
#
#     3.dictionary       {keys:values}

# %%
# mutable data type list example
l = [1,2,44,"ajay","manoj",True]
l
# Out:
# [1, 2, 44, 'ajay', 'manoj', True]

# %%
l[0] = 10000 # it is performing  mutability we can change the index of list
l
# Out:
# [10000, 2, 44, 'ajay', 'manoj', True]

# %%
l[-2]= "vijay solanki"
l
# Out:
# [10000, 2, 44, 'ajay', 'vijay solanki', True]

# %%
# set
s={1,2,3,4,5,5,4,3,2,10}
s
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
s.add(1)
s
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
s.add(14444)
s
# Out:
# {1, 2, 3, 4, 5, 10, 14444}

# %%
l.append("rajiv dattta")
l
# Out:
# [10000, 2, 44, 'ajay', 'vijay solanki', True, 'rajiv dattta']

# %%
l.remove("ajay")
l
# Out:
# [10000, 2, 44, 'vijay solanki', True, 'rajiv dattta']

# %%
l[4:]
# Out:
# [True, 'rajiv dattta']

# %%
l[:-2]
# Out:
# [10000, 2, 44, 'vijay solanki']

# %%
l
# Out:
# [10000, 2, 44, 'vijay solanki', True, 'rajiv dattta']

# %%
d={"dad":123,"mom":456}
d
# Out:
# {'dad': 123, 'mom': 456}

# %%
d["dad"]=789
d
# Out:
# {'dad': 789, 'mom': 456}

# %%
d.keys()
# Out:
# dict_keys(['dad', 'mom'])

# %%
d.values()
# Out:
# dict_values([789, 456])

# %% [markdown]
# # Immutable data types
#
# 1. string >>> sequence of characters
# 2.tuple>>>> it is oredered but immutable     (1,2,4,5,)

# %%
# string
s = "i am vijay solanki"
s
# Out:
# 'i am vijay solanki'

# %%
s[0] = 10000 # it does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-159d6374072d> in <cell line: 0>()
# ----> 1 s[0] = 10000 # it does not support item assignment
#
# TypeError: 'str' object does not support item assignment

# %%
s[:3]
# Out:
# 'i a'

# %%
s[:8]
# Out:
# 'i am vij'

# %%
len(s)
# Out:
# 18

# %%
gritings="hello MR. "
name = input("enter your name  ")
print(gritings+name)
# Out:
# enter your namevijay
# hello MR. vijay

# %%
name = input("enter your name  ")
age = int(input("enter your age  "))
print(f"hello MR.   {name}"+f"   your age is {age}")
# Out:
# enter your name  vijay solanki
# enter your age  22
# hello MR.   vijay solanki   your age is 22

# %%
s.upper()
s
# Out:
# 'I AM VIJAY SOLANKI'

# %%
s.lower()
# Out:
# 'i am vijay solanki'

# %%
s.capitalize()
# Out:
# 'I am vijay solanki'

# %%
s
# Out:
# 'i am vijay solanki'

# %%
# tuple
t=(1,2,"sanjay","ravi")
t
# Out:
# (1, 2, 'sanjay', 'ravi')

# %%
type(t)
# Out:
# tuple

# %%
t=list(t)

# %%
type(t)
# Out:
# list

# %%
t1=(1,2,"vijay","sanjay") # string comperihension
t2 =(4,5,"ravina",23,24444)
[print(i,j)for i in t1 for j in t2]
# Out:
# 1 4
# 1 5
# 1 ravina
# 1 23
# 1 24444
# 1 22222
# 2 4
# 2 5
# 2 ravina
# 2 23
# 2 24444
# 2 22222
# vijay 4
# vijay 5
# vijay ravina
# vijay 23
# vijay 24444
# vijay 22222
# sanjay 4
# sanjay 5
# sanjay ravina
# sanjay 23
# sanjay 24444
# sanjay 22222
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
t[0]
# Out:
# 1

# %%
t[-2]=00000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-63b346c72a04> in <cell line: 0>()
# ----> 1 t[-2]=00000
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Q.3 What are the main difference between list And tuple in python?
#    1. # list
#   - list is mutable and ordered data type
#   - it allows indexing and modification
#
#    2. # tuple
#   - tuples are immutable
#   - it also has indexing conept
#   - but it does not allows modification

# %%
# list
l = [4,4545,"vijay","rahul"]
l
# Out:
# [4, 4545, 'vijay', 'rahul']

# %%
t = (4,"sany","tahir")
t
# Out:
# (4, 'sany', 'tahir')

# %%
l.append("naman")
l
# Out:
# [4, 4545, 'vijay', 'rahul', 'naman']

# %%
l.remove("naman")
l
# Out:
# [4, 4545, 'vijay', 'rahul']

# %%
t.append("nayan")
t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-087e969b51ef> in <cell line: 0>()
# ----> 1 t.append("nayan")
#       2 t
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t[1]=1000 # that is main difference
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6a948f614b30> in <cell line: 0>()
# ----> 1 t[1]=1000
#
# TypeError: 'tuple' object does not support item assignment

# %%
l[1]=1000
l
# Out:
# [4, 1000, 'vijay', 'rahul']

# %%
l[-2]=103232
l
# Out:
# [4, 1000, 103232, 'rahul']

# %%
t[1]
# Out:
# 'sany'

# %%
l[1]
# Out:
# 1000

# %% [markdown]
# # Q.4  Describe how dictionaries store data.
#   - Dictionaries store data in the form of key and values pair
#   dict = {my name : vijay, my father name : kishor}

# %%
# creation of dictionary
students_roll_no  = {"rahul":"18115c04050","ravi":"18115c04058"}
students_roll_no
# Out:
# {'rahul': '18115c04050', 'ravi': '18115c04058'}

# %%
students_roll_no["rahul"]
# Out:
# '18115c04050'

# %%
students_roll_no["ravi"]
# Out:
# '18115c04058'

# %%
students_roll_no["vijay"]="18115c04059"
students_roll_no
# Out:
# {'rahul': '18115c04050', 'ravi': '18115c04058', 'vijay': '18115c04059'}

# %%
students_roll_no.keys()
students_roll_no.values()
# Out:
# dict_values(['18115c04050', '18115c04058', '18115c04059'])

# %%
students_roll_no.items()
# Out:
# dict_items([('rahul', '18115c04050'), ('ravi', '18115c04058'), ('vijay', '18115c04059')])

# %%
students_roll_no.pop("rahul")
# Out:
# '18115c04050'

# %%
students_roll_no
# Out:
# {'ravi': '18115c04058', 'vijay': '18115c04059'}

# %%
students_roll_no.popitem()
# Out:
# ('vijay', '18115c04059')

# %%
students_roll_no
# Out:
# {'ravi': '18115c04058'}

# %%
students_roll_no.update({"vijay":"18115c04059"})
students_roll_no
# Out:
# {'ravi': '18115c04058', 'vijay': '18115c04059'}

# %%
students_roll_no.clear()

# %%
students_roll_no
# Out:
# {}

# %% [markdown]
# # Q.5  Why might you use a set instead of a list in python?
# We might use a set instead of a list in python, because it removes all the duplicacy and gives us unique result
#
#
# if we have any duplicacy in any table, we can use set to remove all the duplicacy And also we can typecast it into the least and use is list

# %%
# use set to remove dupicacy and typcast it into list
s = {"vijay","vijay","rahul","rahul rathod","vijay solanki","ravi","ravi",52,52,52,2,2,4,4,6,6,6,6,6,7,8,888,888,88,}
s
# Out:
# {2,
#  4,
#  52,
#  6,
#  7,
#  8,
#  88,
#  888,
#  'rahul',
#  'rahul rathod',
#  'ravi',
#  'vijay',
#  'vijay solanki'}

# %%
type(s)
# Out:
# set

# %%
s=list(s)
s
# Out:
# [2,
#  4,
#  6,
#  7,
#  8,
#  'rahul rathod',
#  52,
#  'ravi',
#  'rahul',
#  888,
#  'vijay',
#  'vijay solanki',
#  88]

# %%
type(s)
# Out:
# list

# %%
s.append("manoik")
s
# Out:
# [2,
#  4,
#  6,
#  7,
#  8,
#  'rahul rathod',
#  52,
#  'ravi',
#  'rahul',
#  888,
#  88,
#  'manoik',
#  'manoik']

# %%
s.pop()
s.remove("vijay")
s.remove("vijay solanki")
s
# Out:
# [2, 4, 6, 7, 8, 'rahul rathod', 52, 'ravi', 'rahul', 888]

# %%
s[:5]
# Out:
# [2, 4, 6, 7, 8]

# %%
s.append("vijay solanki")
s.append("vijay")
s.append("vijay")
s.append("vijay")

# %%
s
# Out:
# [2,
#  4,
#  6,
#  7,
#  8,
#  'rahul rathod',
#  52,
#  'ravi',
#  'rahul',
#  888,
#  'vijay solanki',
#  'vijay',
#  'vijay',
#  'vijay']

# %%
s=tuple(s)
s
# Out:
# (2,
#  4,
#  6,
#  7,
#  8,
#  'rahul rathod',
#  52,
#  'ravi',
#  'rahul',
#  888,
#  'vijay solanki',
#  'vijay',
#  'vijay',
#  'vijay')

# %%
s=set(s) # now it only gives us unique values
s
# Out:
# {2,
#  4,
#  52,
#  6,
#  7,
#  8,
#  888,
#  'rahul',
#  'rahul rathod',
#  'ravi',
#  'vijay',
#  'vijay solanki'}

# %% [markdown]
# # Q.6  What is string in a python? How it is different from a list?
#   #     String
#   - String is a data type in a python. It uses to store homogeneous data in python
#   - It stores same type of data
#   - it is immutable object
#   - It stores sequence of character
#   - it uses the "    " or '   ' symbol
#
#   # list
#    - List users heterogeneous data means any type of data it can store It can store string , number, float , boolean values,  complex number etc
#    - it is mutable object

# %%
# string
s = "i am vijay solanki"
s
# Out:
# 'i am vijay solanki'

# %%
s[5]
# Out:
# 'v'

# %%
s[5:10]
# Out:
# 'vijay'

# %%
s[11:18]
# Out:
# 'solanki'

# %%
s.replace("vijay","vijay solanki")
# Out:
# 'i am vijay solanki solanki'

# %%
s.count("vijay")
# Out:
# 1

# %%
s.count("v")
# Out:
# 1

# %%
s= "ssff00","hthy",655
s
# Out:
# ('ssff00', 'hthy', 655)

# %%
type(s)
# Out:
# tuple

# %%
names = "ff",545,55
type(names)
# Out:
# tuple

# %%
names = str(names)

# %%
type(names)
# Out:
# str

# %%
names=names,"fg"

# %%
type(names)
names = names,695
names
type(names)
# Out:
# tuple

# %% [markdown]
# # Q.7  How do tuple ensure data integrity in python?
#   - Tuples are immutable to ensure that their contents remain constant throughout their lifecycle, guaranteeing data integrity and reliability. This immutability allows tuples to be used as keys in dictionaries and elements in sets, as they can be hashed.

# %% [markdown]
# # Q.8  What is a hash table and how it relate to dictionaries in python?
#   - In Python, a hash table is a data structure that's implemented as a dictionary. A hash table stores key-value pairs, where the key is generated using a hash function.
#
#   - How hash tables work
# A hash function generates a unique result for each value
# The hash value of a key determines the bucket where the data is stored
# Hash tables are efficient, with an average time complexity of
#
#  for search, insertion, and deletion
# Why hash tables are useful They provide fast access to data and They have excellent average-case performance.
# How dictionaries are used in Python
# Dictionaries are mutable data types, so you can update them as needed
# You can use dictionaries to count the number of times each item appears in a collection
# Examples of using dictionaries
# Mapping employee names to their employee IDs
# Mapping student names to their student IDs
# Counting the number of times each word appears in a sentence

# %% [markdown]
# # Q.9  Can list contains different type of data types in python?
#   - yes lsts can contains Different types of data types
#   - List is mutable and have a indexing concept

# %%
lis = ["vijay",1,2,3,True,(1,2,3),{1,"vijay"},{"mom":123},3+5j]
lis
# Out:
# ['vijay', 1, 2, 3, True, (1, 2, 3), {1, 'vijay'}, {'mom': 123}, (3+5j)]

# %%
lis.append("vijay")
lis
# Out:
# ['vijay',
#  1,
#  2,
#  3,
#  True,
#  (1, 2, 3),
#  {1, 'vijay'},
#  {'mom': 123},
#  (3+5j),
#  'vijay']

# %% [markdown]
# # Q.10 Explain why string are immutable in python?
#   - Strings in Python are “immutable” which means they can not be changed after they are created. Some other immutable data types are integers, ...

# %%
st = "vijay anand arivanadan"
st
# Out:
# 'vijay anand arivanadan'

# %%
type(st)
# Out:
# str

# %%
st[2]=2 # it is immutable it can not be modify after creation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7bb0c44c5f25> in <cell line: 0>()
# ----> 1 st[2]=2
#
# TypeError: 'str' object does not support item assignment

# %%
st.count("a")
# Out:
# 7

# %% [markdown]
# # Q.11 What advantages do dictionaries offer over lists for certain task?
#  - So it is more efficient to use dictionaries for the searching of elements as it can be carried out in a much faster manner. Lists are used when it is important to maintain the order of the elements and dealing with data that may get changed in the future.
#
#  - A list can store any data type. In contrast, keys in the dictionary can be of any immutable data type, and values can be of any data type. Lists perform faster for ordered operations like sorting, while dictionaries perform faster for lookup operations.14 Jun 2024

# %%
l = ["vijay","sanjay",12,15,4655]
if "sanjay" in l:
    print("yes")
else:
  print("no")
# Out:
# yes

# %%
roll = {"sanjay":"18115C04058","vijay":"18115C04059"}
if "sanjay" in roll:
    print("yes")
# Out:
# yes

# %%
roll.copy()
# Out:
# {'sanjay': '18115C04058', 'vijay': '18115C04059'}

# %%
roll.fromkeys("vijay")
# Out:
# {'v': None, 'i': None, 'j': None, 'a': None, 'y': None}

# %%
roll.get("vijay")
# Out:
# '18115C04059'

# %%
roll.items()
# Out:
# dict_items([('sanjay', '18115C04058'), ('vijay', '18115C04059')])

# %% [markdown]
# # Q.12 Describe a scenario where using a tuple would be preferable over a list
#   - If you're defining a constant set of values and all you're ever going to do with it is iterate through it, use a tuple instead of a list.
#   - tuples can contain mutable objects
#   - if we employee and its id once defined can not be changed
#   - it does not supports item assignments
#   -

# %%
epid = (1544,5456565,65565,65656,665656,65656,656)
epid
# Out:
# (1544, 5456565, 65565, 65656, 665656, 65656, 656)

# %%
type(epid)
# Out:
# tuple

# %%
epid[2]=232323 # it uses when you dont want to any value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-873636849b12> in <cell line: 0>()
# ----> 1 epid[2]=232323
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Q.13 How do sets handle duplicate values in python?
#    -  Items of a set in python are immutable (unchangeable), do not duplicate values, and unordered. Thus, items in a set do not appear in a stipulated manner, i.e., they can appear in a different order every time it is used. Due to this, set items cannot be referred to by key or index

# %%
sets = {12,"vijay","2222","vijay","vijay","rahul","Rahul"}
sets
# Out:
# {12, '2222', 'Rahul', 'rahul', 'vijay'}

# %%
sets.add("vijay")
sets
# Out:
# {12, '2222', 'Rahul', 'rahul', 'vijay'}

# %%
sets.remove("vijay")
sets
# Out:
# {12, '2222', 'Rahul', 'rahul'}

# %%
sets.pop()
sets
# Out:
# {12, 'Rahul', 'rahul'}

# %%
sets[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d3627dfb5037> in <cell line: 0>()
# ----> 1 sets[0]
#
# TypeError: 'set' object is not subscriptable

# %%
sets.clear()
sets
# Out:
# set()

# %%
type(sets)
# Out:
# set

# %%
sets = list(sets)
sets
# Out:
# ['2222', 'rahul', 'vijay', 12, 'Rahul']

# %%
sets.append("vijay")
sets
# Out:
# ['2222', 'rahul', 'vijay', 12, 'Rahul', 'vijay']

# %%
sets = tuple(sets)
sets
# Out:
# ('2222', 'rahul', 'vijay', 12, 'Rahul', 'vijay')

# %%
sets = set(sets)
sets
# Out:
# {12, '2222', 'Rahul', 'rahul', 'vijay'}

# %% [markdown]
# # **PRACTICAL QUESTIONS......**
# ## Q.1 Write the code to create a string with your name and print it.

# %%
name = input("plesse enter your name  ")
age = input("enter your age  ")
print("hello MR. ",name + "  your age is ",age)
# Out:
# plesse enter your name  vijay solanki

# %% [markdown]
# # Q.2 Write a code to find the length of string. "Hello World" .

# %%
s = "hello world"
print("length of string ",s + "   is   ",len(s))
# Out:
# length of string  hello world   is    11

# %% [markdown]
# # Q.3 Write a code to slice the first 3 character from the string " Python programming"

# %%
s = "python programming"
s[:3]
# Out:
# 'pyt'

# %% [markdown]
# # Q.4 Write a code to convert the string "hello" to uppercase

# %%
s = "hello"
s.upper()
# Out:
# 'HELLO'

# %% [markdown]
# # Q.5 Write a code to replace the word "apple" with "orange" in the string "i like apple".

# %%
s = "i like apple"
s.replace("apple","orange")
# Out:
# 'i like orange'

# %% [markdown]
# # Q.6 Write a code to create a list with numbers 1 to 5 and print it.

# %%
l = [1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Q.7 Write a code to append the number 10 to the list [1234].

# %%
l = [1,2,3,4]
l.append(10)
l
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# # Q.8 Write a code to remove the number three from the list. [1,2,3,4]

# %%
l = [1,2,3,4]
l.remove(3)
l
# Out:
# [1, 2, 4]

# %% [markdown]
# # Q.9 Write a code to access the second element in the list.["a","b","c","d"]

# %%
l = ["a","b","c","d"]
l[1]
# Out:
# 'b'

# %% [markdown]
# # Q 10 Write a code to reverse the list.[10,20,30,40,50]

# %%
l = [10,20,30,40,50]
l[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# # Q.11 Write a code to create a couple with the element 10,20,30 and print it.

# %%
t = (10,20,30)
t
# Out:
# (10, 20, 30)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# # Q.12 Write a code to access the first element of the tuple. (Apple,banana,orange)

# %%
t = ("apple","banana","orange")
t[0]
# Out:
# 'apple'

# %% [markdown]
# # Q.13 Write the code to count how many times the number 2 appears in the tuple. (1,2,3,2,4,2)

# %%
t = (1,2,3,2,4,2)
t.count(2)
# Out:
# 3

# %% [markdown]
# # Q.14 Write a code to find the index of the element "cat" in the tuple ("dog","cat","rabbit")

# %%
t =("dog","cat","rabbit")
t.index("cat")
# Out:
# 1

# %% [markdown]
# # Q.15 Write a code to cheque if the element "banana" is in the tuple ("apple","orange","banana")

# %%
t = ("apple","orange","banana")
if "banana" in t:
  print("yes")
else:
  print("no")
# Out:
# yes

# %% [markdown]
# # Q.16 Write a code to create a set with the element 12345 and print it.

# %%
se = {1,2,3,4,5}
se
# Out:
# {1, 2, 3, 4, 5}

# %%
type(se)
# Out:
# set

# %% [markdown]
# # Q.17 Write a code to add the element 6 to the set. {1234}

# %%
myset = {1,2,3,4}
myset.add(6)

# %%
myset
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# # Q.18 Now repeated questions comes so I did not do that again
